# %% [markdown]
# # 多句话语音合成
#
# sb 2024-6-11

# %% [markdown]
# ## 导入工具包

# %%
import torchaudio
import torch
from ChatTTS import ChatTTS
import soundfile
from IPython.display import Audio

# %% [markdown]
# ## 载入预训练模型

# %%
chat = ChatTTS.Chat()

# %%
# 加载默认下载的模型
chat.load(compile=False) # 设置为Flase获得更快速度，设置为True获得更佳效果
# Out:
# True

# %% [markdown]
# ## 输入需语音合成的文字

# %%
texts = [
    '学人工智能，应该从Python编程开始',
    'Welcome to the world of Artificial Intelligence, where technology really matters',
    '臣妾要告发熹贵妃私通，秽乱后宫，罪不容诛！',
    '那夜的酒，并不足以让我动情',
    '你还有多少惊喜是朕不知道的',
    '人工智能是本世纪最重要的技术突破，但也为人类带来伦理道德、隐私保护、就业结构这些新问题',
    'Generative Artificial Intelligence, is the most important technology [break]in 21 century, but I think human will be more and more lazy',
]

# %% [markdown]
# ## 语音合成模型推理

# %%
wavs = chat.infer(texts)
# Out:
# found invalid characters: {'！'}
# found invalid characters: {'1', '2'}
# text:   0%|          | 1/384(max) [00:00,  7.67it/s]We detected that you are passing `past_key_values` as a tuple of tuples. This is deprecated and will be removed in v4.47. Please convert your cache or use an appropriate `Cache` class (https://huggingface.co/docs/transformers/kv_cache#legacy-cache-format)
# text:  12%|█▎        | 48/384(max) [00:00, 107.78it/s]
# code:  19%|█▉        | 388/2048(max) [00:02, 153.40it/s]

# %% [markdown]
# ## 试听

# %%
Audio(wavs[0], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(wavs[1], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(wavs[2], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(wavs[4], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(wavs[5], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 导出保存为音频文件

# %%
torchaudio.save("output/output_d2.wav", torch.from_numpy(wavs[3]).unsqueeze(0), 24000)
