# %% [markdown]
# # 封装函数`sb_tts.py`
#
# sb 2024-6-12

# %% [markdown]
# ## 导入函数

# %%
from sb_tts import *

# %% [markdown]
# ## 调用函数

# %%
wavs = sb_tts('我今天真的Feel Good，跑通了语音合成的开源项目，真的特别感谢SB的代码教程！')
# Out:
# found invalid characters: {'！'}
# text:   0%|          | 1/384(max) [00:00,  8.35it/s]We detected that you are passing `past_key_values` as a tuple of tuples. This is deprecated and will be removed in v4.47. Please convert your cache or use an appropriate `Cache` class (https://huggingface.co/docs/transformers/kv_cache#legacy-cache-format)
# text:  10%|█         | 39/384(max) [00:00, 118.55it/s]
# code:  18%|█▊        | 368/2048(max) [00:01, 188.06it/s]

# %%
wavs = sb_tts('学人工智能的第一步，当然是Python编程')
# Out:
# text:   5%|▌         | 21/384(max) [00:00, 180.48it/s]
# code:   9%|▉         | 181/2048(max) [00:00, 187.44it/s]

# %%
Audio(wavs[0], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 通过函数参数控制口语化、笑声、停顿程度

# %%
wavs = sb_tts('在别人眼里 [uv_break] 你是[laugh]黑寡妇，[uv_break]在我这儿 [uv_break] 你就是 [uv_break] 吉祥物 [laugh]',oral=2, laugh=9, bk=3)
# Out:
# text:   8%|▊         | 29/384(max) [00:00, 181.51it/s]
# code:  11%|█         | 226/2048(max) [00:01, 188.04it/s]

# %%
Audio(wavs[0], rate=24000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
